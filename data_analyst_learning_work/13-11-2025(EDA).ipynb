# %%
# !Pip install matplotlib 
# !Pip install seaborn

# %%
# !python -m pip install --upgrade pip

# %%
# !python -m pip install --upgrade pip

# %%
import pandas as pd  
import  seaborn as  sns 
import  matplotlib.pyplot as  plt

# %%
df =  pd.read_csv('C:\\Users\\Admin\\pandas\\titanic - titanic.csv')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df.dropna(subset=['Cabin'], inplace=True)

# %%
#  EDA = exploratory Data analysis :- 

# univariate = Analysis  on a single  independent column
# bivariate =  Analysis  on two column
# multiivariate = Analysis  on more than two(2) column

# %%
#   data type  
#  numerical  data :- continous  data : -  age(year,month,day),height 
# categorical  data :- descrete data ---->total numer of employee ,martial

# %%
import matplotlib.pyplot as plt # visualization library
import seaborn as  sns # matplotlib's updated version is seaborn

# %%
# univerted  analysis : -

# %%
# now we  use categorical  columns work

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    47
# 1    44
# Name: count, dtype: int64

# %%
sns.countplot(x = df['Survived']) # single columns   use for single columns 
sns.countplot(x = df['Pclass'])
df['Pclass'].value_counts()
# Out:
# Pclass
# 1    80
# 2     7
# 3     4
# Name: count, dtype: int64

# %%
# if  we want to  see actual  value  then  we use  value_counts()
df['Survived'].value_counts().plot(kind='bar')  #use for multi columns
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie')
# we use this on discreted data ,also  we use countplot for discrete data ()
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct =  '%.2f') #,autopct  mesans auto  percentage
# Out:
# <Axes: ylabel='count'>

# %%
# use  pi chart  weh  we  have  2  or  3 sub categories  , is  more  then  2  and 3  sub categories then  use  bar chart

# %%
# now we use  or work  on numeric columns work

# %%
# if  we have  numeric data the we use  histogram  
# becuse it find  the distribution

# %%
plt.hist(x=df['Age'])
plt.show()

# %%
# that means age 20 or at 30 people goes there high fro hist

# %%
# displot  ko  histplot  nay  replce kar diyaa to  ab hame  his plot  use kartay hay

# %%
sns.histplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
# outlier  :- which flectuate the value of mean(total nummer of elemnet/total number of frequency ) that why we remove it

# %%
# 3. Boxplot
# for find our outliers

# 1. Lower fence
# 2. 25% data
# 3. IQR (Inter Quartile Range) (75% - 25%)
# 4. 75% data
# 5. upper fence


# x = 1,2,3,4,5
# mean = (1+2+3+4+5)/5 = 15/5 = 3

# x = 1,2,3,4,5,100
# mean = (15+100)/6 = 115/6 = 19.3   ### HERE 100 IS OUTLIER

# %%
sns.boxplot(x= df['Age'])
# Lower fence = lower boundary (limit) 
# 13-11-25 in 49:43
# uper fence = uper boundary (limit)
# Out:
# <Axes: xlabel='Age'>
