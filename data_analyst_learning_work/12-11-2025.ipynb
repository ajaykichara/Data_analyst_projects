# %%
import pandas as pd  

import os  
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\pandas'

# %%
df = pd.read_csv('C:\\Users\\Admin\\pandas\\placement - placement.csv')
df.sample()
# Out:
#     cgpa  resume_score  placed
# 83   7.6          8.08       1

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.info() # all  information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.describe() # statically  view of  data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
top_left_corner_df  = df.iloc[:4,:3]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,['cgpa','placed']]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
s = df.dtypes
s
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty  # Returns True if the DataFrame has zero rows (completely empty)
              # Returns False if the DataFrame has one or more rows
b
# Out:
# False

# %%
df.isnull().sum() # fro check  missing value
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df = df.dropna() # for  remove  missing  row  or  full  row remove

# %%
i = df.ndim # number of axes(it is 2)
i  #by  default  df  is  2d
# Out:
# 2

# %%
d = df.shape  # shape = rows(n) ,columns(n)
d
# Out:
# (100, 3)

# %%
df.shape[0] # show  how  many  rows  in df  
df.shape[1] # show  how many  column in df
# Out:
# 3

# %%
d = df.size  # rows count * columns count 
d            # df.size = total number of elements in DataFrame
# Out:
# 300

# %%
h  = df.values  # df.values returns all data as a NumPy array without row and column labels
h
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df2 = df.copy()

# %%
# assending  order  = min----->max
p = df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
# What is astype()?

# Used to change the data type of a column or entire DataFrame

# %%
# x = df.astype(int) 
# type  conversion 
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].astype(str)
df.dtypes
# Out:
# cgpa             object
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['cgpa'] = df['cgpa'].astype(int)
df.dtypes
# Out:
# cgpa              int64
# resume_score    float64
# placed            int64
# dtype: object

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0     8          6.52       1
# 1     6          5.17       0
# 2     8          8.86       1
# 3     6          7.27       1
# 4     7          7.30       1

# %%
df['resume_score'] = df['resume_score'].astype(int)

# %%
df.sample(3)
# Out:
#     cgpa  resume_score  placed
# 45     8             5       1
# 85     6             5       0
# 43     8             7       1

# %%
# w = df.abs() abs() returns the absolute value, converting negative numbers to positive."
# w

# %%
df['cgpa'] = df['cgpa'].add(1)

# %%
s = df.count()  #Count non-null values
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
s = df.max() #Count non-null values
s
# Out:
# cgpa            10
# resume_score     9
# placed           1
# dtype: int64

# %%
# df['city'].max()  maximum city give  first letter  check  acording  to  alphabate    in string

# %%
g = df.filter(items=['cgpa','placed']) 
              #"Both return the same columns, but filter() provides more flexible selection options."
g
# or  
df[['cgpa','placed']] # second  option of filtering  


# if  want selected  rows  then  use  loc  and  iloc
# Out:
#     cgpa  placed
# 0      9       1
# 1      7       0
# 2      9       1
# 3      7       1
# 4      8       1
# ..   ...     ...
# 95     7       0
# 96     9       1
# 97     7       0
# 98     9       1
# 99     7       0
#
# [100 rows x 2 columns]

# %%
s = df.filter(items=[5,6],axis=0) ###axis  =0  means row wise  operation  
s
# Out:
#    cgpa  resume_score  placed
# 5     9             6       1
# 6     6             7       0

# %%
s = df.filter(like = '5',axis=0)  
s
# Out:
#     cgpa  resume_score  placed
# 5      9             6       1
# 15     9             5       1
# 25     8             5       1
# 35     9             7       1
# 45     9             5       1
# 50     9             6       1
# 51     7             7       0
# 52     6             7       0
# 53     7             7       0
# 54     6             7       0
# 55     7             6       1
# 56     7             6       0
# 57     7             7       0
# 58     7             7       0
# 59     6             7       0
# 65     7             8       0
# 75     7             7       1
# 85     7             5       0
# 95     7             6       0

# %%
s = df.to_dict()
s
# Out:
# {'cgpa': {0: 9,
#   1: 7,
#   2: 9,
#   3: 7,
#   4: 8,
#   5: 9,
#   6: 6,
#   7: 7,
#   8: 7,
#   9: 8,
#   10: 7,
#   11: 6,
#   12: 7,
#   13: 9,
#   14: 8,
#   15: 9,
#   16: 9,
#   17: 8,
#   18: 6,
#   19: 7,
#   20: 6,
#   21: 7,
#   22: 7,
#   23: 7,
#   24: 9,
#   25: 8,
#   26: 7,
#   27: 6,
#   28: 8,
#   29: 7,
#   30: 8,
#   31: 6,
#   32: 6,
#   33: 9,
#   34: 9,
#   35: 9,
#   36: 9,
#   37: 10,
#   38: 7,
#   39: 8,
#   40: 9,
#   41: 9,
#   42: 7,
#   43: 9,
#   44: 6,
#   45: 9,
#   46: 6,
#   47: 8,
#   48: 6,
#   49: 6,
#   50: 9,
#   51: 7,
#   52: 6,
#   53: 7,
#   54: 6,
#   55: 7,
#   56: 7,
#   57: 7,
#   58: 7,
#   59: 6,
#   60: 6,
#   61: 7,
#   62: 6,
#   63: 9,
#   64: 8,
#   65: 7,
#   66: 9,
#   67: 7,
#   68: 7,
#   69: 9,
#   70: 8,
#   71: 8,
#   72: 8,
#   73: 6,
#   74: 6,
#   75: 7,
#   76: 10,
#   77: 6,
#   78: 6,
#   79: 6,
#   80: 8,
#   81: 7,
#   82: 8,
#   83: 8,
#   84: 6,
#   85: 7,
#   86: 7,
#   87: 6,
#   88: 9,
#   89: 6,
# ...

# %%
s = df.to_string()

# %%
e = df.to_csv('new_df_df')

# %%
s = df.rename(columns = {'cgpa':'updated_cgpa','resume_score':'sem_mark'})
s# columns name rename
# Out:
#     updated_cgpa  sem_mark  placed
# 0              9         6       1
# 1              7         5       0
# 2              9         8       1
# 3              7         7       1
# 4              8         7       1
# ..           ...       ...     ...
# 95             7         6       0
# 96             9         7       1
# 97             7         7       0
# 98             9         5       1
# 99             7         6       0
#
# [100 rows x 3 columns]

# %%
df['half']  = df['cgpa'].where(df['cgpa']>7,other = 0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0     9             6       1     9
# 1     7             5       0     0
# 2     9             8       1     9
# 3     7             7       1     0
# 4     8             7       1     8
# 5     9             6       1     9
# 6     6             7       0     0
# 7     7             6       0     0
# 8     7             6       0     0
# 9     8             7       1     8

# %%
df = pd.read_csv('C:\\Users\\Admin\\pandas\\covid_toy - covid_toy.csv')
df.sample()
# Out:
#     age gender  fever cough       city has_covid
# 78   11   Male  100.0  Mild  Bangalore       Yes

# %%
df.dropna()
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [90 rows x 6 columns]

# %%
df.groupby('has_covid').size()
# Out:
# has_covid
# No     55
# Yes    45
# dtype: int64

# %%
# task :- 

# Create an Employee DataFrame in which you have (Emp_ID, Emp_Name, Department, Salary)
# Column and you have total 8 rows in your dataframe and you have to calculate :

# (1) Top 3 data
# (2) Bottom 4 data
# (3) Create a new column in which whose salary is greater than 20000 only shows 1 rest all are 0.
# (4) Check Staticaly view and info() of dataframe ?

# %%
d = {
    "Emp_ID":[101,102,103,104,105,106,107,108],
    "Emp_Name":['ajay','aman','pinku','tina','chinki','harsh','tarun','neelam'],
    "Department":['it','manager','client_issue','it','manager','client_issue','technistion','it'],
    "SaLary":[120000,5000,21000,120000,5000,21000,2500,120000]
}

# %%
df = pd.DataFrame(d)
df
# Out:
#    Emp_ID Emp_Name    Department  SaLary
# 0     101     ajay            it  120000
# 1     102     aman       manager    5000
# 2     103    pinku  client_issue   21000
# 3     104     tina            it  120000
# 4     105   chinki       manager    5000
# 5     106    harsh  client_issue   21000
# 6     107    tarun   technistion    2500
# 7     108   neelam            it  120000

# %%
df.head(3)
# Out:
#    Emp_ID Emp_Name    Department  SaLary
# 0     101     ajay            it  120000
# 1     102     aman       manager    5000
# 2     103    pinku  client_issue   21000

# %%
df.tail(4)
# Out:
#    Emp_ID Emp_Name    Department  SaLary
# 4     105   chinki       manager    5000
# 5     106    harsh  client_issue   21000
# 6     107    tarun   technistion    2500
# 7     108   neelam            it  120000

# %%
df['salary_greater_20000'] =  df['SaLary'].where(df['SaLary']>20000,other = 0)
df['salary_greater_20000'] =  df['salary_greater_20000'].where(df['salary_greater_20000']==0,other = 1)

# %%
df
# Out:
#    Emp_ID Emp_Name    Department  SaLary  salary_greater_20000
# 0     101     ajay            it  120000                     1
# 1     102     aman       manager    5000                     0
# 2     103    pinku  client_issue   21000                     1
# 3     104     tina            it  120000                     1
# 4     105   chinki       manager    5000                     0
# 5     106    harsh  client_issue   21000                     1
# 6     107    tarun   technistion    2500                     0
# 7     108   neelam            it  120000                     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Emp_ID                8 non-null      int64
#  1   Emp_Name              8 non-null      object
#  2   Department            8 non-null      object
#  3   SaLary                8 non-null      int64
#  4   salary_greater_20000  8 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#           Emp_ID         SaLary  salary_greater_20000
# count    8.00000       8.000000              8.000000
# mean   104.50000   51812.500000              0.625000
# std      2.44949   56898.366472              0.517549
# min    101.00000    2500.000000              0.000000
# 25%    102.75000    5000.000000              0.000000
# 50%    104.50000   21000.000000              1.000000
# 75%    106.25000  120000.000000              1.000000
# max    108.00000  120000.000000              1.000000
